# %%
import numpy as np
import pandas as pd
import csv
import matplotlib.pyplot as plt

# %%
with open('pricing test data (3).csv', 'r', newline='') as csvfile:
    reader = csv.reader(csvfile, delimiter=';')
    l = []
    k = 0
    for row in reader:
        if k == 0:
            pass
        else:
            l.append([float(row[0], )] + row[1:])
        k+=1
    df = pd.DataFrame(l)
df.columns = ['user id','event_time','event name','group','country','source']
df.to_csv('1.csv', index=False)
df
# Out:
# ---------------------------------------------------------------------------
#
# ValueError                                Traceback (most recent call last)
#
# c:\Users\Dima\Desktop\A-B test\pricing.ipynb Cell 2 in <cell line: 1>()
#
#       <a href='vscode-notebook-cell:/c%3A/Users/Dima/Desktop/A-B%20test/pricing.ipynb#X11sZmlsZQ%3D%3D?line=6'>7</a>         pass
#
#       <a href='vscode-notebook-cell:/c%3A/Users/Dima/Desktop/A-B%20test/pricing.ipynb#X11sZmlsZQ%3D%3D?line=7'>8</a>     else:
#
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Dima/Desktop/A-B%20test/pricing.ipynb#X11sZmlsZQ%3D%3D?line=8'>9</a>         l.append([float(row[0])] + row[1:])
#
#      <a href='vscode-notebook-cell:/c%3A/Users/Dima/Desktop/A-B%20test/pricing.ipynb#X11sZmlsZQ%3D%3D?line=9'>10</a>     k+=1
#
#      <a href='vscode-notebook-cell:/c%3A/Users/Dima/Desktop/A-B%20test/pricing.ipynb#X11sZmlsZQ%3D%3D?line=10'>11</a> df = pd.DataFrame(l)
#
#
#
# ...

# %%
import tqdm

with open('1.csv', 'r', newline='') as csvfile:
    reader = csv.reader(csvfile)
    l = []
    k = 0
    for row in reader:
        if k == 0:
            pass
        else:
            try:
                if '/' in row[1]:
                    row[1] = row[1].split(sep='/')[1] + '/' + row[1].split(sep='/')[0] + '/' + row[1].split(sep='/')[2]
            except: pass
            l.append(row)
        # print(row)
        k+=1
    df = pd.DataFrame(l)
df.columns = ['user id','event_time','event name','group','country','source']
df.to_csv('2.csv', index=False)
df.head(100)
# Out:
#                  user id event_time event name       group        country  \
# 0   56164500000000000.00      44928      click  test(6.99)         Canada
# 1   56195200000000000.00      44928      click  test(6.99)          Chile
# 2   56198900000000000.00      44928      click  test(6.99)       Colombia
# 3   56095700000000000.00      44928      click  test(6.99)          Italy
# 4    5616300000000000.00      44928      click  test(6.99)      Mauritius
# ..                   ...        ...        ...         ...            ...
# 95  57410500000000000.00  16/2/2023      click  test(6.99)  United States
# 96  57731500000000000.00  20/2/2023      click  test(6.99)  United States
# 97  58231900000000000.00  27/2/2023      click  test(6.99)  United States
# 98  61086100000000000.00      45050      click  test(6.99)         France
# 99  61273900000000000.00      45050      click  test(6.99)  United States
#
#    source
# 0
# 1
# 2
# 3
# 4
# ..    ...
# 95
# 96
# 97
# 98
# 99
#
# ...
